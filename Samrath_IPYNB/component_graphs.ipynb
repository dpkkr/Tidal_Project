# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.fft import fft, rfft, ifft, irfft
from scipy.fft import fftfreq, rfftfreq
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import plotly.express as px
import matplotlib.pyplot as plt
import math

for num in [17,18,19]:
    file_path = f'{str(num)}_new.xlsx'
    
    # Read the Excel file with headers in the first row
    df = pd.read_excel(file_path, header=0)  # header=0 to use the first row as the header
    
    # Ignore the 1st column (column A which contains dates)
    df_subset = df.iloc[:,1:]
    
    # Concatenate all rows into a single list and ignore values that are 0
    data = df_subset.values.flatten().tolist()
    data = [100*value for value in data]
    #data = [math.nan if x==0 else x for x in data]
    n = len(data)
    
    sampling_rate = 24 # It's used as a sample spacing, because 24 hours in a day
    rfft_data = rfft(data)
    rfft_freq = rfftfreq(n, d=1.0/sampling_rate)
    norm_rfft_amp = 2/n*np.abs(rfft(data))
    
    amplitudes = []
    n = len(norm_rfft_amp)
    for i in range(1,n-1):
        if (norm_rfft_amp[i]>norm_rfft_amp[i-1] and norm_rfft_amp[i]>norm_rfft_amp[i+1]):
            amplitudes.append(norm_rfft_amp[i])
    amplitudes.sort(reverse=True)
    
    df = pd.DataFrame({'Amplitude':amplitudes})[:11]
    output_file = f'{str(num)}_output.xlsx'
    df.to_excel(output_file)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Number of files and number of plots
num_files = 6
num_plots = 10

# Initialize a list to hold the data from each file
data = []

# Loop through each file and read the 'Amplitude' column
for i in [17,18,19,20,21,22]:
    file_path = f'component_17_{i}.xlsx'
    df = pd.read_excel(file_path)
    data.append(df['Amplitude'].tolist())

# Convert the list to a DataFrame for easier manipulation
data_df = pd.DataFrame(data).T

# Plot the data
for i in range(num_plots):
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, num_files + 1), data_df.iloc[i, :], marker='o', linestyle='-') #number of files gives error cuz some files have no values, and are thus eliminated
    plt.title(f'Plot of {i+1}th Component from Each File')
    plt.xlabel('Year number')
    plt.ylabel('Amplitude')
    plt.xticks(range(1, num_files + 1))
    plt.ylim(0)
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt

# Number of files and number of plots
num_files = 6
num_plots = 10

# Initialize a list to hold the data from each file
data = []

# Loop through each file and read the 'Amplitude' column
for i in [17,18,19,20,21,22]:
    file_path = f'component_17_{i}.xlsx'
    df = pd.read_excel(file_path)
    data.append(df['Speed (degs/hour)'].tolist())

# Convert the list to a DataFrame for easier manipulation
data_df = pd.DataFrame(data).T

# Plot the data
for i in range(num_plots):
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, num_files + 1), data_df.iloc[i, :], marker='o', linestyle='-') #number of files gives error cuz some files have no values, and are thus eliminated
    plt.title(f'Plot of {i+1}th Component from Each File')
    plt.xlabel('Year number')
    plt.ylabel('Speed (degs/hour')
    plt.xticks(range(1, num_files + 1))
    plt.ylim(0)
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt

# Number of files and number of plots
num_files = 6
num_plots = 10

# Initialize a list to hold the data from each file
data = []

# Loop through each file and read the 'Amplitude' column
for i in [17,18,19,20,21,22]:
    file_path = f'component_17_{i}.xlsx'
    df = pd.read_excel(file_path)
    data.append(df['Amplitude'].tolist())

# Convert the list to a DataFrame for easier manipulation
data_df = pd.DataFrame(data).T

# Plot the data
for i in range(num_plots):
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, num_files + 1), data_df.iloc[i, :], marker='o', linestyle='-') #number of files gives error cuz some files have no values, and are thus eliminated
    plt.title(f'Plot of {i+1}th Component from Each File')
    plt.xlabel('Year number')
    plt.ylabel('Amplitude')
    plt.xticks(range(1, num_files + 1))
    plt.ylim(0)
    plt.grid(True)
    plt.show()
